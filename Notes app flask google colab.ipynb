# %%
import os
os.mkdir('templates')
os.mkdir('static')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-1-8fce76cd860a> in <module>()
#       1 import os
# ----> 2 os.mkdir('templates')
#       3 os.mkdir('static')
#
# FileExistsError: [Errno 17] File exists: 'templates'

# %%
var='''

 <!DOCTYPE html>
<html lang="en" dir="ltr">

<head>
    <meta charset="utf-6">
    <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.1.3/css/bootstrap.min.css"
        integrity="sha384-MCw98/SFnGE8fJT3GXwEOngsV7Zt27NXFoaoApmYm81iuXoPkFOJwJ8ERdknLPMO" crossorigin="anonymous">
    <script src="https://code.jquery.com/jquery-3.3.1.slim.min.js"
        integrity="sha384-q8i/X+965DzO0rT7abK41JStQIAqVgRVzpbzo5smXKp4YfRvH+8abtTE1Pi6jizo"
        crossorigin="anonymous"></script>
    <script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.3/umd/popper.min.js"
        integrity="sha384-ZMP7rVo3mIykV+2+9J3UJ46jBk0WLaUAdn689aCwoqbBJiSnjAK/l8WvCWPIPm49"
        crossorigin="anonymous"></script>
    <script src="https://stackpath.bootstrapcdn.com/bootstrap/4.1.3/js/bootstrap.min.js"
        integrity="sha384-ChfqqxuZUCnJSK3+MXmPNIyE6ZbWh2IMqE241rYiqJxyMiZ6OW/JmZQ5stwEULTy"
        crossorigin="anonymous"></script>
    <title>Notes</title>
</head>

<style>
    body {
        background-repeat: no-repeat;
        background-color: rgba(0, 0, 0, 0.938);
        background-image: url("https://images.unsplash.com/photo-1598928506311-c55ded91a20c?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=1950&q=80");
       background-size: cover;
       background-position-x: right;
    }
 a {
        font-size: 20px;
        margin-left: 180px;
    }

    a:hover {
        font-size: 26px;
    }

    #container {
        padding-left: 3px;
        padding-top: 11px;
        margin: 20px;
    }

    p {
        color: rgb(199, 199, 199);
        font-family: serif;
        font-size: 30px;
        font-weight: lighter;

    }

    .para {
        font-size: 25px;
        font-weight: 1px;
    }

    #btn { padding: 3px;
        background-color: rgb(255, 255, 255);
        border: 0.1px solid black;
        border-radius: 18px;
        font-size: 18px;

    }

    #btn:hover {
        background-color: rgb(221, 221, 191);
        box-shadow:5px 5px 10px rgb(85, 84, 84);
        border: 1px solid rgb(0, 0, 0);
    }

    #btn2 {padding: 3px;
        background-color: white;
        border: 0.1px solid black;
        border-radius: 18px;
        font-size: 18px;
    }

    #btn2:hover {
        background-color: rgb(221, 221, 191);
        box-shadow: 5px 5px 10px rgb(85, 84, 84);
        border: 1px solid rgb(0, 0, 0);
    }

    #btn3 {padding: 3px;
        background-color: white;
        border: 0.1px solid black;
        border-radius: 18px;
        font-size: 18px;
    }

    #btn3:hover {
        background-color: rgb(221, 221, 191);
        box-shadow: 5px 5px 10px rgb(85, 84, 84);
        border: 1px solid rgb(0, 0, 0);
    }
</style>

<body>

   <nav style="background-color: rgb(223, 192, 146); height: 62px;" class="navbar navbar-expand-lg navbar-light">
        <div class="navbar-nav">
            <a class="nav-item nav-link" href="/index">Home</a>
            <a class="nav-item nav-link" href="/add">add room</a>
            <a class="nav-item nav-link" href="/list"> list</a>
            <a class="nav-item nav-link" href="/del">Unavailable Rooms</a>
        </div>
    </nav>


      
</body>

</html>
'''
file=open("templates/index.html","w")
file.write(var)
file.close()

# %%
var='''
<!DOCTYPE html>
<html lang="en" dir="ltr">

<head>
    <meta charset="utf-6">
    <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.1.3/css/bootstrap.min.css"
        integrity="sha384-MCw98/SFnGE8fJT3GXwEOngsV7Zt27NXFoaoApmYm81iuXoPkFOJwJ8ERdknLPMO" crossorigin="anonymous">
    <script src="https://code.jquery.com/jquery-3.3.1.slim.min.js"
        integrity="sha384-q8i/X+965DzO0rT7abK41JStQIAqVgRVzpbzo5smXKp4YfRvH+8abtTE1Pi6jizo"
        crossorigin="anonymous"></script>
    <script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.3/umd/popper.min.js"
        integrity="sha384-ZMP7rVo3mIykV+2+9J3UJ46jBk0WLaUAdn689aCwoqbBJiSnjAK/l8WvCWPIPm49"
        crossorigin="anonymous"></script>
    <script src="https://stackpath.bootstrapcdn.com/bootstrap/4.1.3/js/bootstrap.min.js"
        integrity="sha384-ChfqqxuZUCnJSK3+MXmPNIyE6ZbWh2IMqE241rYiqJxyMiZ6OW/JmZQ5stwEULTy"
        crossorigin="anonymous"></script>
    <title>Notes</title>
</head>
<style>
    body {
        background-color: rgb(255, 235, 233);
 }
#div {
        background-color: rgb(240, 127, 83);
        color: rgb(250, 251, 252);

    }
     a {
        font-size: 25px;
        margin-left: 260px;
    }

    a:hover {
        font-size: 26px;
    }
</style>

<body>

   <nav class="navbar navbar-expand-lg navbar-light bg-light">
        <div class="navbar-nav"> 
         <a class="nav-item nav-link" href="/index">Home</a>
          <a class="nav-item nav-link" href="/add">Add room</a>
          <a class="nav-item nav-link" href="/del">remove room</a>
        </div>
    </nav>
    <div id="div" class="jumbotron">
        <h1 style="text-align: center; font-weight: lighter;">There You Go! These are available rooms.</h1> <br>
        <ul style="margin-left: 370px;">
            {% for x in hotel %}
            <li>{{x['id']}} - {{x['name']}}</li> <br>
            {% endfor %}
        </ul>
    </div>
    <div style="height: 40px; background-color: rgb(255, 215, 188); width: 500px; margin-left: 450px;">
    <p style="color: rgb(248, 164, 61); text-align: center; margin-top: 10px;">To add or delete any of them , go to Add or Delete page respectively</p>
</div>
    
</body>

</html>

'''
file=open("templates/list.html","w")
file.write(var)
file.close()

# %%
var='''
<!DOCTYPE html>
<html lang="en" dir="ltr">

<head>
    <meta charset="utf-6">
    <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.1.3/css/bootstrap.min.css"
        integrity="sha384-MCw98/SFnGE8fJT3GXwEOngsV7Zt27NXFoaoApmYm81iuXoPkFOJwJ8ERdknLPMO" crossorigin="anonymous">
    <script src="https://code.jquery.com/jquery-3.3.1.slim.min.js"
        integrity="sha384-q8i/X+965DzO0rT7abK41JStQIAqVgRVzpbzo5smXKp4YfRvH+8abtTE1Pi6jizo"
        crossorigin="anonymous"></script>
    <script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.3/umd/popper.min.js"
        integrity="sha384-ZMP7rVo3mIykV+2+9J3UJ46jBk0WLaUAdn689aCwoqbBJiSnjAK/l8WvCWPIPm49"
        crossorigin="anonymous"></script>
    <script src="https://stackpath.bootstrapcdn.com/bootstrap/4.1.3/js/bootstrap.min.js"
        integrity="sha384-ChfqqxuZUCnJSK3+MXmPNIyE6ZbWh2IMqE241rYiqJxyMiZ6OW/JmZQ5stwEULTy"
        crossorigin="anonymous"></script>
    <title>Notes</title>
</head>
<style>
    input {
        border: 2px solid rgb(153, 153, 153);
        border-radius: 5px;
        box-shadow: 5px 5px 7px rgb(94, 91, 91);
        align-content: center;
        height: 150px;
        width: 200px;
    }

    input:hover {
        border: 1px rgb(252, 227, 231);
        box-shadow: 10px 10px 15px rgb(125, 137, 155);
    }

    a {
        font-size: 25px;
        margin-left: 250px;
    }

    a:hover {
        font-size: 26px;
    }
    #btn:hover{
        cursor: grab;
        box-shadow: 7px 7px 13px rgb(62, 15, 94);
    }
</style>

<body>

    <nav style="background-color: rgb(221, 204, 204);" class="navbar navbar-expand-lg navbar-light">
        <div class="navbar-nav">
            <a class="nav-item nav-link" href="/index">Home</a>
            <a class="nav-item nav-link" href="/add">Add Room</a>
            <a class="nav-item nav-link" href="/list">Rooms list</a>
          
        </div>
    </nav>

    <div
        class="jumbotron">
        <h1 style="font-weight: lighter; text-align: center;">Enter the Index number of room you want to
            remove from the list</h1>

        <form action="/delete_data">
            <!-- <p
        style="text-align: center; font-family: Verdana, Geneva, Tahoma, sans-serif;  font-weight: lighter; font-size: 20px;">
        Serial no.:</p> -->
            <div style="padding-left: 560px; margin: 20px;">
                <input style="width: 350px;" type='txt' name='id'> <br> <br>
                <input style="height: 70px; " id="btn" type='submit' value='delete room'>
            </div>
        </form>
        <p
            style="color: rgb(122, 122, 122); padding-left: 650px; font-size: 1px; font-family: Cambria, Cochin, Georgia, Times, 'Times New Roman', serif;">
            {{ msg }}</p>
    </div>
</body>

</html>
'''
file=open("templates/delete.html","w")
file.write(var)
file.close()

# %%
var='''
<!DOCTYPE html>
<html lang="en" dir="ltr">

<head>
    <meta charset="utf-6">
    <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.1.3/css/bootstrap.min.css"
        integrity="sha384-MCw98/SFnGE8fJT3GXwEOngsV7Zt27NXFoaoApmYm81iuXoPkFOJwJ8ERdknLPMO" crossorigin="anonymous">
    <script src="https://code.jquery.com/jquery-3.3.1.slim.min.js"
        integrity="sha384-q8i/X+965DzO0rT7abK41JStQIAqVgRVzpbzo5smXKp4YfRvH+8abtTE1Pi6jizo"
        crossorigin="anonymous"></script>
    <script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.3/umd/popper.min.js"
        integrity="sha384-ZMP7rVo3mIykV+2+9J3UJ46jBk0WLaUAdn689aCwoqbBJiSnjAK/l8WvCWPIPm49"
        crossorigin="anonymous"></script>
    <script src="https://stackpath.bootstrapcdn.com/bootstrap/4.1.3/js/bootstrap.min.js"
        integrity="sha384-ChfqqxuZUCnJSK3+MXmPNIyE6ZbWh2IMqE241rYiqJxyMiZ6OW/JmZQ5stwEULTy"
        crossorigin="anonymous"></script>
    <title>Notes</title>
</head>
<style>
    input {
        border: 0.1px solid rgb(255, 255, 255);
        height: 160px;
        width: 200px;
        box-shadow: 4px 4px 10px rgb(208, 177, 238);
        padding: 20px;
    }
    #inp:hover{
 box-shadow: 5px 5px 17px rgb(85, 94, 226);
 cursor: grab;
    }
     a {
        font-size: 25px;
        margin-left: 250px;
    }

    a:hover {
        font-size: 26px;
    }
</style>

<body>

    <nav class="navbar navbar-expand-lg navbar-light bg-light">
        <div class="navbar-nav">
                    <a class="nav-item nav-link" href="/index">Home</a>
          <a class="nav-item nav-link" href="/list">All rooms</a>
          <a class="nav-item nav-link" href="/del">Removed Rooms</a>  
        </div>
    </nav>
    <div style="height: 450px;background-repeat:no-repeat ; background-image: url('https://images.unsplash.com/photo-1615859131861-052f0641a60e?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=2011&q=80');"
        class="jumbotron">
        <h1 style="font-family: Verdana, Geneva, Tahoma, sans-serif; font-weight: lighter; text-align: center;"> Add a room</h1>
      <form style="padding-left: 500px;" action="add_data">

            <input type='txt' name='room'>
            <input id="inp" style="font-weight: lighter; height: 60px;" type='submit' value='New room'>
        </form>
        <p style="color: rgb(122, 126, 126); padding-left: 620px; padding-top: 20px;">{{ msg }}</p>
    </div>
</body>

</html>

'''
file=open("templates/add.html","w")
file.write(var)
file.close()

# %%
import sqlite3  
  
con = sqlite3.connect("Hotel.db")  
print("Database created")  
  
con.execute("create table hotel (id INTEGER PRIMARY KEY AUTOINCREMENT, name INT NOT NULL)")  
  
print("Table created")  
  
con.close()
# Out:
# Database created
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-6-c1913e204b44> in <module>()
#       4 print("Database created")
#       5
# ----> 6 con.execute("create table hotel (id INTEGER PRIMARY KEY AUTOINCREMENT, name INT NOT NULL)")
#       7
#       8 print("Table created")
#
# OperationalError: table hotel already exists

# %%
# !pip install flask_ngrok

# %%
from flask import Flask,render_template,url_for,redirect,request
import sqlite3 
from flask_ngrok import run_with_ngrok
 
 
app=Flask(__name__)
run_with_ngrok(app)

@app.route('/')
def index():
  return render_template('index.html')


@app.route('/index')
def home():
  return render_template('index.html')


@app.route('/add', methods=['GET', 'POST'])
def add():

  return render_template('add.html')

@app.route('/add_data', methods=['GET', 'POST'])
def add_data():
  #msg = "Not added!"
  if request.method == 'GET':
    name = request.args.get('room')
    print(name)
    with sqlite3.connect("Hotel.db") as con:
      
      cur = con.cursor()  
      cur.execute("INSERT into hotel (name) values (?)",[name])  
      con.commit()
      msg = "New room added!"
  print(name)
  return render_template('add.html',msg =msg )





@app.route('/list')
def list1():
  con = sqlite3.connect("Hotel.db")  
  con.row_factory = sqlite3.Row  
  cur = con.cursor()  
  cur.execute("select * from hotel")  
  rows = cur.fetchall()  
    
  return render_template('list.html',hotel=rows)


@app.route('/del')
def delete():
  return render_template('delete.html')


@app.route('/delete_data')
def delete_data():
  id = request.args.get('id')
  with sqlite3.connect("Hotel.db") as con:
    try:
      cur = con.cursor()  
      cur.execute("delete from hotel where id = ?",[id])  
      msg = " One room removed"  
    except:  
      msg = "Sorry! Something went wrong :("  
    finally:  
      return render_template('delete.html',msg = msg)



if __name__=='__main__':
  app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://e6fba5e5d094.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# 127.0.0.1 - - [09/Jul/2021 11:04:36] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2021 11:04:38] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2021 11:04:39] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Jul/2021 11:04:40] "GET /add HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2021 11:04:42] "GET /add HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2021 11:04:46] "GET /add_data?room=22 HTTP/1.1" 200 -
# 22
# 22
# 127.0.0.1 - - [09/Jul/2021 11:04:49] "GET /del HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2021 11:04:51] "GET /del HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2021 11:04:53] "GET /list HTTP/1.1" 200 -
# ...
